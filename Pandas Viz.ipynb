# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df1 = pd.read_csv('df1', index_col=0)
df2 = pd.read_csv('df2')

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
sns.pairplot(df2)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 2000-01-01 to 2002-09-26
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       1000 non-null   float64
#  1   B       1000 non-null   float64
#  2   C       1000 non-null   float64
#  3   D       1000 non-null   float64
# dtypes: float64(4)
# memory usage: 79.1+ KB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       10 non-null     float64
#  1   b       10 non-null     float64
#  2   c       10 non-null     float64
#  3   d       10 non-null     float64
# dtypes: float64(4)
# memory usage: 448.0 bytes

# %%
df1.plot()

# %%
plt.figure(figsize=(12,6))
df1['A'].plot()

# %%
sns.distplot(df1['A'], label ='My Hist Plot')
plt.legend()
plt.show()

# %%
fig, axes = plt.subplots()
df1['A'].hist()
axes.set_xlabel('Historgram')
axes.set_ylabel('Density')
axes.set_title('My Hist Plot')
# Out:
# Text(0.5, 1.0, 'My Hist Plot')

# %%
df1.plot.scatter(x='A', y='B')

# %%
sns.jointplot(x=df1['A'], y=df1['B'])

# %%
plt.figure(figsize=(30,6))
df2.plot.area(alpha=0.5)

# %%
sns.relplot(data=df1, x='A', y='B')

# %%
sns.barplot(data=df1)

# %%
sns.countplot(data=df1, x='A')

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       10 non-null     float64
#  1   b       10 non-null     float64
#  2   c       10 non-null     float64
#  3   d       10 non-null     float64
# dtypes: float64(4)
# memory usage: 448.0 bytes

# %%
sns.barplot(data=df2, estimator=count)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-c7df182813e8> in <module>
# ----> 1 sns.barplot(data=df2, estimator=count)
#
# NameError: name 'count' is not defined

# %%
df2.plot.bar(stacked=True)

# %%
plt.figure(figsize=(12,6))
df1['B'].plot(color='red')

# %%
df1.plot.scatter(x='A', y='B', c='C',s=df1['D']*200, cmap='coolwarm', figsize=(12,6))

# %%
sns.jointplot(x=df1['A'],y=df1['B'], cmap='jet')

# %%
sns.boxplot(data=df2)

# %%
df2.plot.box()

# %%
hexplot = sns.jointplot(x=df1['A'], y=df1['B'], kind='hex', cmap='Oranges')
plt.colorbar()
plt.show()

# %%
df1.plot.hexbin(x='A', y='B', cmap='Oranges')

# %%
sns.distplot(a=df2['a'], hist=False)

# %%
plt.style.use('seaborn-dark-palette')
ax=sns.distplot(a=df2['a'], hist=False, label='a')
sns.distplot(a=df2['b'], hist=False, label='b')
sns.distplot(a=df2['c'], hist=False, label='c')
sns.distplot(a=df2['d'], hist=False, label='d')
ax.set_title('Density Plots')
ax.set_ylabel('Values')
# Out:
# Text(0, 0.5, 'Values')

# %%
df2.plot.kde()

# %%
df2.plot.density()
